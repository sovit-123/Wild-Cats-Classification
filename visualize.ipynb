# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Taking a Look at Some of the Photos

# %%
files_white = os.listdir('data/white')

plt.figure(figsize=(12, 8))
for i in range(4):
    plt.subplot(220 + i + 1)
    sample_image = random.choice(files_white)
    image = tf.keras.preprocessing.image.load_img('data/white/' + sample_image)
    plt.imshow(image)
    
files_golden = os.listdir('data/golden')

plt.figure(figsize=(12, 8))
for i in range(4):
    plt.subplot(220 + i + 1)
    sample_image = random.choice(files_golden)
    image = tf.keras.preprocessing.image.load_img('data/golden/' + sample_image)
    plt.imshow(image)
    
files_puma = os.listdir('data/puma')

plt.figure(figsize=(12, 8))
for i in range(4):
    plt.subplot(220 + i + 1)
    sample_image = random.choice(files_puma)
    image = tf.keras.preprocessing.image.load_img('data/puma/' + sample_image)
    plt.imshow(image)

# %%
golden_tiger_count = 0
white_tiger_count = 0
puma_count = 0

golden_tiger_count = len(os.listdir('data/golden')) 
white_tiger_count = len(os.listdir('data/white')) 
puma_count = len(os.listdir('data/puma')) 

print('Number of golden tiger photos:', golden_tiger_count)
print('Number of white tiger photos:', white_tiger_count)
print('Number of puma photos:', puma_count)
# Out:
# Number of golden tiger photos: 374
# Number of white tiger photos: 377
# Number of puma photos: 351
